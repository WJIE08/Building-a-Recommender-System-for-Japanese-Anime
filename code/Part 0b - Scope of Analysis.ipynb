# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import urllib.parse as urlparse


import os
import re
from PIL import Image
from sklearn.metrics.pairwise import cosine_similarity
import pickle
import shutil

import sys
import warnings
import timeit

# %% [markdown]
# ## 1. Import Data
#
# There are two datasets to be imported:
# a. Animes Dataset: This contains the metadata of the animes which we scrapped from: https://myanimelist.net/
# b. Reviews Dataset: This contains the ratings given by users for animes and is obtained from kaggle website: https://www.kaggle.com/marlesson/myanimelist-dataset-animes-profiles-reviews

# %%
df_anime = pd.read_csv('./data/dataset_EDA_Topic_14022021.csv')
print('There are {} rows and {} columns in the animes dataset'.format(df_anime.shape[0], df_anime.shape[1]))
# Out:
# There are 17489 rows and 91 columns in the animes dataset
# C:\Users\khimg\anaconda3\envs\cs5242\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (12,13,22,50,51,52,53,54,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,80,81,82,83,84) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_review = pd.read_csv('./data/reviews.csv')
print('There are {} rows and {} columns in reviews dataset'.format(df_review.shape[0], df_review.shape[1]))
# Out:
# There are 192112 rows and 7 columns in reviews dataset

# %% [markdown]
# **Examine the reviews data**

# %%
df_review.head()
# Out:
#       uid          profile  anime_uid  \
# 0  255938   DesolatePsyche      34096
# 1  259117        baekbeans      34599
# 2  253664             skrn      28891
# 3    8254     edgewalker00       2904
# 4  291149  aManOfCulture99       4181
#
#                                                 text  score  \
# 0  \n           \n         \n           \n       ...      8
# 1  \n           \n         \n           \n       ...     10
# 2  \n           \n         \n           \n       ...      7
# 3  \n           \n         \n           \n       ...      9
# 4  \n           \n         \n           \n       ...     10
#
#                                               scores  \
# 0  {'Overall': '8', 'Story': '8', 'Animation': '8...
# 1  {'Overall': '10', 'Story': '10', 'Animation': ...
# 2  {'Overall': '7', 'Story': '7', 'Animation': '9...
# 3  {'Overall': '9', 'Story': '9', 'Animation': '9...
# 4  {'Overall': '10', 'Story': '10', 'Animation': ...
#
#                                             link
# 0  https://myanimelist.net/reviews.php?id=255938
# 1  https://myanimelist.net/reviews.php?id=259117
# 2  https://myanimelist.net/reviews.php?id=253664
# 3    https://myanimelist.net/reviews.php?id=8254
# 4  https://myanimelist.net/reviews.php?id=291149

# %%
# check columns of data available
df_review.columns
# Out:
# Index(['uid', 'profile', 'anime_uid', 'text', 'score', 'scores', 'link'], dtype='object')

# %%
df_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192112 entries, 0 to 192111
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   uid        192112 non-null  int64
#  1   profile    192112 non-null  object
#  2   anime_uid  192112 non-null  int64
#  3   text       192112 non-null  object
#  4   score      192112 non-null  int64
#  5   scores     192112 non-null  object
#  6   link       192112 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 10.3+ MB

# %%
# check if uid is unique 
# uid refers to the id of review according to the data owner on kaggle and hence we expect it to be unique
df_review.duplicated(['uid']).sum()
# Out:
# 61593

# %%
# examine records where the uids are duplicates
dup_ids = df_review[df_review.duplicated(['uid'])]['uid']
df_review[df_review['uid'].isin(dup_ids)].sort_values('uid')
# Out:
#            uid        profile  anime_uid  \
# 36254        1          Xinil          1
# 163348       1          Xinil          1
# 36318       10          Xinil        263
# 163484      10          Xinil        263
# 185200      12  running_lemon        210
# ...        ...            ...        ...
# 53898   325734        AnimeBW      21339
# 43185   325738       fenclair      34798
# 176806  325738       fenclair      34798
# 46087   325747     Doug_Dugle        849
# 181060  325747     Doug_Dugle        849
#
#                                                      text  score  \
# 36254   \n           \n         \n           \n       ...     10
# 163348  \n           \n         \n           \n       ...     10
# 36318   \n           \n         \n           \n       ...     10
# 163484  \n           \n         \n           \n       ...     10
# 185200  \n           \n         \n           \n       ...      7
# ...                                                   ...    ...
# 53898   \n           \n         \n           \n       ...      7
# 43185   \n           \n         \n           \n       ...     10
# 176806  \n           \n         \n           \n       ...     10
# 46087   \n           \n         \n           \n       ...      8
# 181060  \n           \n         \n           \n       ...      8
#
#                                                    scores  \
# 36254   {'Overall': '10', 'Story': '8', 'Animation': '...
# 163348  {'Overall': '10', 'Story': '8', 'Animation': '...
# 36318   {'Overall': '10', 'Story': '10', 'Animation': ...
# 163484  {'Overall': '10', 'Story': '10', 'Animation': ...
# 185200  {'Overall': '7', 'Story': '6', 'Animation': '8...
# ...                                                   ...
# 53898   {'Overall': '7', 'Story': '0', 'Animation': '0...
# 43185   {'Overall': '10', 'Story': '9', 'Animation': '...
# 176806  {'Overall': '10', 'Story': '9', 'Animation': '...
# 46087   {'Overall': '8', 'Story': '10', 'Animation': '...
# 181060  {'Overall': '8', 'Story': '10', 'Animation': '...
#
#                                                  link
# 36254        https://myanimelist.net/reviews.php?id=1
# 163348       https://myanimelist.net/reviews.php?id=1
# 36318       https://myanimelist.net/reviews.php?id=10
# 163484      https://myanimelist.net/reviews.php?id=10
# 185200      https://myanimelist.net/reviews.php?id=12
# ...                                               ...
# 53898   https://myanimelist.net/reviews.php?id=325734
# 43185   https://myanimelist.net/reviews.php?id=325738
# 176806  https://myanimelist.net/reviews.php?id=325738
# 46087   https://myanimelist.net/reviews.php?id=325747
# 181060  https://myanimelist.net/reviews.php?id=325747
#
# [122458 rows x 7 columns]

# %%
# remove duplicated uids since they are the same
df_review = df_review.drop_duplicates(['uid'])
df_review.shape
# Out:
# (130519, 7)

# %%
# check again if there are duplicated ratings
df_review.duplicated(["uid","anime_uid", "score"]).sum()
# Out:
# 0

# %%
# count the number of reviews given by each user
reviews_count = df_review[['profile', 'uid']].groupby(['profile']).size().reset_index(name='counts')
reviews_count['counts'].describe()
# Out:
# count    47885.000000
# mean         2.725676
# std          8.217880
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max        611.000000
# Name: counts, dtype: float64

# %% [markdown]
# **Examine animes dataset**

# %%
df_anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17489 entries, 0 to 17488
# Data columns (total 91 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                17489 non-null  int64
#  1   Unnamed: 0           17489 non-null  int64
#  2   Unnamed: 0.1         17489 non-null  int64
#  3   Title                17489 non-null  object
#  4   URL                  17489 non-null  object
#  5   English              6982 non-null   object
#  6   Synonyms             10619 non-null  object
#  7   Japanese             17443 non-null  object
#  8   Type                 17489 non-null  object
#  9   Episodes             16998 non-null  float64
#  10  Status               17489 non-null  object
#  11  Aired                17489 non-null  object
#  12  Premiered            4966 non-null   object
#  13  Broadcast            4966 non-null   object
#  14  Producers            17489 non-null  object
#  15  Licensors            17489 non-null  object
#  16  Studios              17489 non-null  object
#  17  Source               17489 non-null  object
#  18  Genres               17489 non-null  object
#  19  Duration             17489 non-null  int64
#  20  Rating               17489 non-null  object
#  21  Score                12364 non-null  float64
#  22  Ranked               15760 non-null  object
#  23  Popularity           17489 non-null  object
#  24  Members              17489 non-null  int64
#  25  Favorites            17489 non-null  int64
#  26  Started              17192 non-null  object
#  27  Ended                8413 non-null   object
#  28  Voters               12364 non-null  float64
#  29  Adaptation           5148 non-null   object
#  30  Alternative version  1408 non-null   object
#  31  Side story           1154 non-null   object
#  32  Spin-off             413 non-null    object
#  33  Synopsis             16612 non-null  object
#  34  Prequel              3030 non-null   object
#  35  Alternative setting  360 non-null    object
#  36  Sequel               3063 non-null   object
#  37  Other                2552 non-null   object
#  38  Summary              450 non-null    object
#  39  Character            390 non-null    object
#  40  Parent story         2023 non-null   object
#  41  Full story           489 non-null    object
#  42  Genre_0              17489 non-null  object
#  43  Genre_1              13208 non-null  object
#  44  Genre_2              8986 non-null   object
#  45  Genre_3              5515 non-null   object
#  46  Genre_4              2949 non-null   object
#  47  Genre_5              1227 non-null   object
#  48  Genre_6              438 non-null    object
#  49  Genre_7              143 non-null    object
#  50  Genre_8              58 non-null     object
#  51  Genre_9              21 non-null     object
#  52  Genre_10             7 non-null      object
#  53  Genre_11             1 non-null      object
#  54  Genre_12             1 non-null      object
#  55  Air_Start            17192 non-null  object
#  56  Air_End              7907 non-null   object
#  57  Duration_Aired       7907 non-null   float64
#  58  Producer_0           9728 non-null   object
#  59  Producer_1           4024 non-null   object
#  60  Producer_2           2156 non-null   object
#  61  Producer_3           1416 non-null   object
#  62  Producer_4           981 non-null    object
#  63  Producer_5           645 non-null    object
#  64  Producer_6           394 non-null    object
#  65  Producer_7           238 non-null    object
#  66  Producer_8           155 non-null    object
#  67  Producer_9           75 non-null     object
#  68  Producer_10          43 non-null     object
#  69  Producer_11          23 non-null     object
#  70  Producer_12          11 non-null     object
#  71  Producer_13          7 non-null      object
#  72  Producer_14          6 non-null      object
#  73  Producer_15          5 non-null      object
#  74  Producer_16          5 non-null      object
#  75  Producer_17          3 non-null      object
#  76  Producer_18          3 non-null      object
#  77  Producer_19          1 non-null      object
#  78  Studio_0             10435 non-null  object
#  79  Studio_1             750 non-null    object
#  80  Studio_2             46 non-null     object
#  81  Studio_3             4 non-null      object
#  82  Studio_4             1 non-null      object
#  83  Studio_5             1 non-null      object
#  84  Studio_6             1 non-null      object
#  85  Anime_Number         17489 non-null  int64
#  86  Dominant_Topic       17489 non-null  float64
#  87  Topic_Perc_Contrib   17489 non-null  float64
#  88  Keywords             17489 non-null  object
#  89  Text                 16604 non-null  object
#  90  Topic_Category       17489 non-null  object
# dtypes: float64(6), int64(7), object(78)
# memory usage: 12.1+ MB

# %%
df_anime.head()
# Out:
#    index  Unnamed: 0  Unnamed: 0.1                                 Title  \
# 0      0           0             0      Fullmetal Alchemist: Brotherhood
# 1      1           1             1  Shingeki no Kyojin: The Final Season
# 2      2           2             2                           Steins;Gate
# 3      3           3             3    Shingeki no Kyojin Season 3 Part 2
# 4      4           4             4                              Gintama°
#
#                                                  URL  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...
# 1  https://myanimelist.net/anime/40028/Shingeki_n...
# 2     https://myanimelist.net/anime/9253/Steins_Gate
# 3  https://myanimelist.net/anime/38524/Shingeki_n...
# 4       https://myanimelist.net/anime/28977/Gintama°
#
#                             English  \
# 0  Fullmetal Alchemist: Brotherhood
# 1      Attack on Titan Final Season
# 2                       Steins;Gate
# 3   Attack on Titan Season 3 Part 2
# 4                  Gintama Season 4
#
#                                             Synonyms  \
# 0  Hagane no Renkinjutsushi: Fullmetal Alchemist,...
# 1  Shingeki no Kyojin Season 4, Attack on Titan S...
# 2                                                NaN
# 3                                                NaN
# 4                                    Gintama' (2015)
#
#                      Japanese Type  Episodes  ... Studio_3 Studio_4 Studio_5  \
# 0  鋼の錬金術師 FULLMETAL ALCHEMIST   TV      64.0  ...      NaN      NaN      NaN
# 1      進撃の巨人 The Final Season   TV      16.0  ...      NaN      NaN      NaN
# 2                 STEINS;GATE   TV      24.0  ...      NaN      NaN      NaN
# 3        進撃の巨人 Season3 Part.2   TV      10.0  ...      NaN      NaN      NaN
# 4                         銀魂°   TV      51.0  ...      NaN      NaN      NaN
#
#   Studio_6 Anime_Number Dominant_Topic Topic_Perc_Contrib  \
# 0      NaN            0            0.0             0.2993
# 1      NaN            1            0.0             0.2820
# 2      NaN            2            1.0             0.3302
# 3      NaN            3            1.0             0.3661
# 4      NaN            4            1.0             0.2368
#
#                                             Keywords  \
# 0  world, human, power, earth, fight, save, war, ...
# 1  world, human, power, earth, fight, save, war, ...
# 2  year, group, team, member, lead, club, face, j...
# 3  year, group, team, member, lead, club, face, j...
# 4  year, group, team, member, lead, club, face, j...
#
#                                                 Text  \
# 0   in order for something to be obtained somethi...
# 1  gabi braun and falco grice have been training ...
# 2  the self proclaimed mad scientist rintarou oka...
# 3  seeking to restore humanity s diminishing hope...
# 4  gintoki shinpachi and kagura return as the fun...
#
#                               Topic_Category
# 0        Anime about war or battles on earth
# 1        Anime about war or battles on earth
# 2  Anime about membership in a club or group
# 3  Anime about membership in a club or group
# 4  Anime about membership in a club or group
#
# [5 rows x 91 columns]

# %%
df_anime.columns
# Out:
# Index(['index', 'Unnamed: 0', 'Unnamed: 0.1', 'Title', 'URL', 'English',
#        'Synonyms', 'Japanese', 'Type', 'Episodes', 'Status', 'Aired',
#        'Premiered', 'Broadcast', 'Producers', 'Licensors', 'Studios', 'Source',
#        'Genres', 'Duration', 'Rating', 'Score', 'Ranked', 'Popularity',
#        'Members', 'Favorites', 'Started', 'Ended', 'Voters', 'Adaptation',
#        'Alternative version', 'Side story', 'Spin-off', 'Synopsis', 'Prequel',
#        'Alternative setting', 'Sequel', 'Other', 'Summary', 'Character',
#        'Parent story', 'Full story', 'Genre_0', 'Genre_1', 'Genre_2',
#        'Genre_3', 'Genre_4', 'Genre_5', 'Genre_6', 'Genre_7', 'Genre_8',
#        'Genre_9', 'Genre_10', 'Genre_11', 'Genre_12', 'Air_Start', 'Air_End',
#        'Duration_Aired', 'Producer_0', 'Producer_1', 'Producer_2',
#        'Producer_3', 'Producer_4', 'Producer_5', 'Producer_6', 'Producer_7',
#        'Producer_8', 'Producer_9', 'Producer_10', 'Producer_11', 'Producer_12',
#        'Producer_13', 'Producer_14', 'Producer_15', 'Producer_16',
#        'Producer_17', 'Producer_18', 'Producer_19', 'Studio_0', 'Studio_1',
#        'Studio_2', 'Studio_3', 'Studio_4', 'Studio_5', 'Studio_6',
#        'Anime_Number', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords',
#        'Text', 'Topic_Category'],
#       dtype='object')

# %%
# check if there are duplicates by URL - URL by right is supposed to be the unique key
df_anime.duplicated(['URL']).sum()
# Out:
# 11

# %%
# examine records where the URLs are duplicates
dup_urls = df_anime[df_anime.duplicated(['URL'])]['URL']
df_anime[df_anime['URL'].isin(dup_urls)].sort_values('URL')
# Out:
#        index  Unnamed: 0  Unnamed: 0.1                                Title  \
# 10299  10299       10299            49                     Waza no Tabibito
# 10300  10300       10300             0                     Waza no Tabibito
# 5999    5999        5999            49  Dakara Boku wa, H ga Dekinai. Recap
# 6000    6000        6000             0  Dakara Boku wa, H ga Dekinai. Recap
# 12050  12050       12050             0                Soba no Hana Saita Hi
# 12049  12049       12049            49                Soba no Hana Saita Hi
# 11550  11550       11550             0            Pororo Hanguk-e Wass-eoyo
# 11549  11549       11549            49            Pororo Hanguk-e Wass-eoyo
# 10649  10649       10649            49                    Aoki Seimei Hoken
# 10650  10650       10650             0                    Aoki Seimei Hoken
# 10999  10999       10999            49                           Love Bites
# 11000  11000       11000             0                           Love Bites
# 5591    5591        5591            41                  Feng Wei Ying Xiong
# 6106    6106        6106             6                  Feng Wei Ying Xiong
# 12499  12499       12499            49               Tokyu Plaza Ginza Open
# 12500  12500       12500             0               Tokyu Plaza Ginza Open
# 10900  10900       10900             0                    Torikaekko Please
# 10899  10899       10899            49                    Torikaekko Please
# 11949  11949       11949            49      Shinya! Tensai Bakabon Specials
# 11950  11950       11950             0      Shinya! Tensai Bakabon Specials
# 11699  11699       11699            49                    Ruri-iro Princess
# 11700  11700       11700             0                    Ruri-iro Princess
#
#                                                      URL  \
# 10299  https://myanimelist.net/anime/10904/Waza_no_Ta...
# 10300  https://myanimelist.net/anime/10904/Waza_no_Ta...
# 5999   https://myanimelist.net/anime/15325/Dakara_Bok...
# 6000   https://myanimelist.net/anime/15325/Dakara_Bok...
# 12050  https://myanimelist.net/anime/26321/Soba_no_Ha...
# 12049  https://myanimelist.net/anime/26321/Soba_no_Ha...
# 11550  https://myanimelist.net/anime/27465/Pororo_Han...
# 11549  https://myanimelist.net/anime/27465/Pororo_Han...
# 10649  https://myanimelist.net/anime/31513/Aoki_Seime...
# 10650  https://myanimelist.net/anime/31513/Aoki_Seime...
# 10999     https://myanimelist.net/anime/32894/Love_Bites
# 11000     https://myanimelist.net/anime/32894/Love_Bites
# 5591   https://myanimelist.net/anime/33759/Feng_Wei_Y...
# 6106   https://myanimelist.net/anime/33759/Feng_Wei_Y...
# 12499  https://myanimelist.net/anime/33884/Tokyu_Plaz...
# 12500  https://myanimelist.net/anime/33884/Tokyu_Plaz...
# 10900  https://myanimelist.net/anime/33898/Torikaekko...
# 10899  https://myanimelist.net/anime/33898/Torikaekko...
# 11949  https://myanimelist.net/anime/38001/Shinya_Ten...
# 11950  https://myanimelist.net/anime/38001/Shinya_Ten...
# 11699  https://myanimelist.net/anime/9212/Ruri-iro_Pr...
# 11700  https://myanimelist.net/anime/9212/Ruri-iro_Pr...
#
#                       English  \
# 10299                     NaN
# 10300                     NaN
# 5999      So, I Can't Play H!
# 6000      So, I Can't Play H!
# 12050                     NaN
# 12049                     NaN
# 11550    Pororo Goes to Korea
# 11549    Pororo Goes to Korea
# 10649                     NaN
# 10650                     NaN
# 10999                     NaN
# 11000                     NaN
# 5591        Beyond the Worlds
# 6106        Beyond the Worlds
# 12499  Tokyu Plaza Ginza Open
# 12500  Tokyu Plaza Ginza Open
# 10900                     NaN
# 10899                     NaN
# 11949                     NaN
# 11950                     NaN
# 11699                     NaN
# 11700                     NaN
#
#                                                 Synonyms  \
# 10299                                                NaN
# 10300                                                NaN
# 5999   Dakara Boku wa, H ga Dekinai Episode 7.5, Daka...
# 6000   Dakara Boku wa, H ga Dekinai Episode 7.5, Daka...
# 12050                                                NaN
# 12049                                                NaN
# 11550                          Pororo Hangug-e Wass-eoyo
# 11549                          Pororo Hangug-e Wass-eoyo
# 10649                                                NaN
# 10650                                                NaN
# 10999                                                NaN
# 11000                                                NaN
# 5591                                        Crazy Heroes
# 6106                                        Crazy Heroes
# 12499                                                NaN
# 12500                                                NaN
# 10900    Let's Trade, Please, Pokemon Song, Pokémon Song
# 10899    Let's Trade, Please, Pokemon Song, Pokémon Song
# 11949  Late Night! Genius Bakabon, Unagi-Inu at Night...
# 11950  Late Night! Genius Bakabon, Unagi-Inu at Night...
# 11699                                   Ruriiro Princess
# 11700                                   Ruriiro Princess
#
#                      Japanese     Type  Episodes  ... Studio_3 Studio_4  \
# 10299                    技の旅人    Movie       1.0  ...      NaN      NaN
# 10300                    技の旅人    Movie       1.0  ...      NaN      NaN
# 5999            だから僕は、Hができない。  Special       1.0  ...      NaN      NaN
# 6000            だから僕は、Hができない。  Special       1.0  ...      NaN      NaN
# 12050                そばの花さいた日      OVA       1.0  ...      NaN      NaN
# 12049                そばの花さいた日      OVA       1.0  ...      NaN      NaN
# 11550            뽀로로가 한국에 왔어요      ONA       1.0  ...      NaN      NaN
# 11549            뽀로로가 한국에 왔어요      ONA       1.0  ...      NaN      NaN
# 10649                青木生命保険CM  Special       1.0  ...      NaN      NaN
# 10650                青木生命保険CM  Special       1.0  ...      NaN      NaN
# 10999              LOVE BITES      ONA       1.0  ...      NaN      NaN
# 11000              LOVE BITES      ONA       1.0  ...      NaN      NaN
# 5591                     疯味英雄      ONA      13.0  ...      NaN      NaN
# 6106                     疯味英雄      ONA      13.0  ...      NaN      NaN
# 12499  Tokyu Plaza Ginza Open  Special       1.0  ...      NaN      NaN
# 12500  Tokyu Plaza Ginza Open  Special       1.0  ...      NaN      NaN
# 10900              とりかえっこプリーズ    Music       1.0  ...      NaN      NaN
# 10899              とりかえっこプリーズ    Music       1.0  ...      NaN      NaN
# 11949              深夜! 天才バカボン  Special      12.0  ...      NaN      NaN
# 11950              深夜! 天才バカボン  Special      12.0  ...      NaN      NaN
# 11699                るり色プリンセス      OVA       2.0  ...      NaN      NaN
# 11700                るり色プリンセス      OVA       2.0  ...      NaN      NaN
#
#       Studio_5 Studio_6 Anime_Number Dominant_Topic Topic_Perc_Contrib  \
# 10299      NaN      NaN        10299            0.0             0.3471
# 10300      NaN      NaN        10300            0.0             0.3481
# 5999       NaN      NaN         5999            3.0             0.2308
# 6000       NaN      NaN         6000            3.0             0.2308
# 12050      NaN      NaN        12050            0.0             0.2000
# 12049      NaN      NaN        12049            0.0             0.2000
# 11550      NaN      NaN        11550            3.0             0.3432
# 11549      NaN      NaN        11549            3.0             0.3460
# 10649      NaN      NaN        10649            3.0             0.2321
# 10650      NaN      NaN        10650            3.0             0.2321
# 10999      NaN      NaN        10999            3.0             0.2407
# 11000      NaN      NaN        11000            3.0             0.2407
# 5591       NaN      NaN         5591            0.0             0.2510
# 6106       NaN      NaN         6106            0.0             0.2510
# 12499      NaN      NaN        12499            2.0             0.2448
# 12500      NaN      NaN        12500            2.0             0.2483
# 10900      NaN      NaN        10900            3.0             0.3594
# 10899      NaN      NaN        10899            3.0             0.3594
# 11949      NaN      NaN        11949            3.0             0.2453
# 11950      NaN      NaN        11950            3.0             0.2453
# 11699      NaN      NaN        11699            0.0             0.2798
# 11700      NaN      NaN        11700            0.0             0.2826
#
#                                                 Keywords  \
# 10299  world, human, power, earth, fight, save, war, ...
# 10300  world, human, power, earth, fight, save, war, ...
# 5999   short, song, special, base, feature, film, inc...
# 6000   short, song, special, base, feature, film, inc...
# 12050  world, human, power, earth, fight, save, war, ...
# 12049  world, human, power, earth, fight, save, war, ...
# 11550  short, song, special, base, feature, film, inc...
# 11549  short, song, special, base, feature, film, inc...
# 10649  short, song, special, base, feature, film, inc...
# 10650  short, song, special, base, feature, film, inc...
# 10999  short, song, special, base, feature, film, inc...
# 11000  short, song, special, base, feature, film, inc...
# 5591   world, human, power, earth, fight, save, war, ...
# 6106   world, human, power, earth, fight, save, war, ...
# 12499  girl, school, make, life, day, love, student, ...
# 12500  girl, school, make, life, day, love, student, ...
# 10900  short, song, special, base, feature, film, inc...
# 10899  short, song, special, base, feature, film, inc...
# 11949  short, song, special, base, feature, film, inc...
# 11950  short, song, special, base, feature, film, inc...
# 11699  world, human, power, earth, fight, save, war, ...
# 11700  world, human, power, earth, fight, save, war, ...
#
#                                                     Text  \
# 10299  humans acquired a perfect source of energy cal...
# 10300  humans acquired a perfect source of energy cal...
# 5999           recap episode aired between episodes and
# 6000           recap episode aired between episodes and
# 12050        an educational film about environmentalism
# 12049        an educational film about environmentalism
# 11550  korean culture and information service ministr...
# 11549  korean culture and information service ministr...
# 10649      tv commercial of aoki life insurance company
# 10650      tv commercial of aoki life insurance company
# 10999     a short animation by nagao takena made in mmd
# 11000     a short animation by nagao takena made in mmd
# 5591      heroes of old appear to return peace to earth
# 6106      heroes of old appear to return peace to earth
# 12499  a commercial made to advertise the grand openi...
# 12500  a commercial made to advertise the grand openi...
# 10900  official music video for suzukisans torikaekko...
# 10899  official music video for suzukisans torikaekko...
# 11949  included with the blu ray and dvd release of s...
# 11950  included with the blu ray and dvd release of s...
# 11699  high school girl ruri is dragged into a battle...
# 11700  high school girl ruri is dragged into a battle...
#
#                                Topic_Category
# 10299     Anime about war or battles on earth
# 10300     Anime about war or battles on earth
# 5999   Anime featuring songs, films or videos
# 6000   Anime featuring songs, films or videos
# 12050     Anime about war or battles on earth
# 12049     Anime about war or battles on earth
# 11550  Anime featuring songs, films or videos
# 11549  Anime featuring songs, films or videos
# 10649  Anime featuring songs, films or videos
# 10650  Anime featuring songs, films or videos
# 10999  Anime featuring songs, films or videos
# 11000  Anime featuring songs, films or videos
# 5591      Anime about war or battles on earth
# 6106      Anime about war or battles on earth
# 12499    Anime about love story set in school
# 12500    Anime about love story set in school
# 10900  Anime featuring songs, films or videos
# 10899  Anime featuring songs, films or videos
# 11949  Anime featuring songs, films or videos
# 11950  Anime featuring songs, films or videos
# 11699     Anime about war or battles on earth
# 11700     Anime about war or battles on earth
#
# [22 rows x 91 columns]

# %%
# remove duplicated records by URLs since they are the same
df_anime = df_anime.drop_duplicates(['URL'])
df_anime.shape
# Out:
# (17478, 91)

# %%
# check the values for TYPE
df_anime['Type'].value_counts()
# Out:
# TV         4966
# OVA        3889
# Movie      3034
# Special    2212
# ONA        1884
# Music      1462
# Unknown      31
# Name: Type, dtype: int64

# %%
# check number of animes with missing synopsis\n",
df_anime['Synopsis'].isnull().sum()
# Out:
# 877

# %% [markdown]
# **Observations:**
# 1. In the reviews dataset, the animes are identified by anime_uid. In the dataset, the anime_uid is masked within the URL: /anime/{anime_uid}/. As such to combine the above two dataset, we need to apply regex to extract the anime_uid info in the animes dataset.
# 2. Observe that there are also many different types. We will restrict our scope to Type == TV and discard the rest.

# %% [markdown]
# ## 2. Identify Animes within Scope for Analysis
#
# Scope of Analysis limited to:
# 1. Animes where Type = 'TV'
# 2. Animes with valid synopsis. The reason for doing this is because one of the collaborative filtering algorithm will be using synopsis to derive similarity score. Thus, to ensure a valid comparison across the different models, we will have to ensure the dataset used is the same.

# %%
# subset Type == TV
df_anime = df_anime[df_anime['Type']=='TV']
df_anime.shape
# Out:
# (4966, 91)

# %%
# subset animes with valid synopsis
df_anime = df_anime[(df_anime['Synopsis'].notnull()) & (df_anime['Synopsis']!=' ')]
df_anime.shape
# Out:
# (4808, 91)

# %% [markdown]
# ## 3. Extract anime_uid for animes dataset

# %%
#retrieve the digits after the "anime/", these digits are the anime uid
df_anime['anime_uid'] = df_anime['URL'].str.extract('anime/(\d+)/')

#convert to integer
df_anime['anime_uid'] = df_anime['anime_uid'].astype(int)

# %% [markdown]
# ## 4. Subset Rating Records for Animes within Scope

# %%
# subset rating records for animes within scope
df_review = df_review[df_review['anime_uid'].isin(df_anime['anime_uid'])]
df_review.shape
# Out:
# (101481, 7)

# %%
# further scale down to look at only users who has more than 1 review
user_multiple_reviews = df_review[df_review.duplicated(['profile'])]['profile']
df_review = df_review[df_review['profile'].isin(user_multiple_reviews)]
df_review.shape
# Out:
# (75921, 7)

# %%
# check number of unique users remaining
len(set(df_review['profile']))
# Out:
# 15363

# %% [markdown]
# ## 5. Output datasets to CSV

# %%
df_review.to_csv('./processed_data/processed_reviews.csv', index=False)
df_anime.to_csv('./processed_data/processed_anime.csv', index=False)

# %% [markdown]
# ## 6. Extract images
#
# Given that we have scoped our reviews and anime dataset, we will discard the images data which we have scrapped but are assessed to be out of scope.

# %%
# specify images directory
images_dir = r'data/images/'
csv_dir = r'data/'

# %%
# subset the indices of the animes retained
animes_idx_retained = df_anime.index.tolist()
len(animes_idx_retained)
# Out:
# 4808

# %%
# check
animes_idx_retained[:10]
# Out:
# [0, 1, 2, 3, 4, 5, 6, 8, 9, 11]

# %%
# create a directory to store the images within scope
try:
    os.mkdir('./processed_data/images/')
except OSError:
    pass

# %%
# Get file names from original images directory
file_names = os.listdir(images_dir)
file_names[0]
# Out:
# 'index_0.jpg'

# %%
# identify images to retain and shift to new folder

animes_retained_img = []

for i in file_names:
    # get the anime index of the image and convert it to int
    anime_name = int(re.findall(r'\d+', i)[0])
    
    if anime_name in animes_idx_retained:    
        src_dir = images_dir + str(i)
        dst_dir = './processed_data/images/'
        shutil.copy(src_dir, dst_dir)
        animes_retained_img.append(anime_name)
    else:
        pass

# %%
# check lenght of animes_retained_img
print(len(animes_retained_img))
# Out:
# 4801

# %%
# check which are the animes which did not have images
animes_no_img = list(set(animes_idx_retained) - set(animes_retained_img))
print(len(animes_no_img))
print(animes_no_img)
# Out:
# 7
# [14211, 12041, 16074, 15788, 12751, 15823, 11580]
